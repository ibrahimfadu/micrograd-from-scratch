# %%
import numpy as np

# %%
import random

# %%
x=[random.uniform(-5,5) for _ in range(5)]

# %%
import matplotlib.pyplot as plt

# %%
x
# Out:
# [-3.231346694103323,
#  -0.2004652061992953,
#  0.014899508389771832,
#  4.900348664708083,
#  3.768342712715725]

# %%
y=[1,2,3,4,5]
plt.plot(x,y)

# %%
class Value():
    def __init__(self,data):
        self.data=data;
        se
    def __repr__(self):
        return f"Value:{self.data}"
